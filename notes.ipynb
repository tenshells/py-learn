# %%
import tkinter as tk
from tkinter import ttk
from PIL import ImageTk


brown="#762A0C"
orange="#E87D22"
white="#ffffff"

#basics
root = tk.Tk()
root.title("Chord Script Generator ")
root.eval("tk::PlaceWindow . center")

#main box
frame1 = tk.Frame(root, width=500, height=600, bg=brown)
# frame1.grid(row=0,column=0)
frame1.pack()
frame1.pack_propagate(False)

#logo
logo_image = ImageTk.PhotoImage(file="cover2.jpg")
logo_widget = tk.Label(frame1, image=logo_image, bg=brown)
logo_widget.image = logo_image
logo_widget.pack()

scales = "Major Dorian Phrygian Lydian Mixolydian Minor Harmonic Minor Carnatic Arabic Byzantine".split()

scale_var = tk.StringVar(frame1, value=scales[0])

scales_dropdown = tk.OptionMenu(frame1,scale_var, *scales)
scales_dropdown.config(font=("TkMenuFont",12), width=10)
menu = frame1.nametowidget(scales_dropdown.menuname)
menu.config(font=("TkMenuFont",12))

scales_dropdown.pack(pady=10)
#label for 1,2,3
tk.Label(
    frame1,
    text="Chords for 1,2,3,4,5,6,7",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

tk.Label(
    frame1,
    text="Chords for 8,9,0,-,=",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

#label for qwert
tk.Label(
    frame1,
    text="Chords for q,w,e,r,t,y,u",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()


tk.Label(
    frame1,
    text="Chords for i,o,p,[,],|",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

#label for asdf
tk.Label(
    frame1,
    text="Chords for a,s,d,f,g,h,j",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

tk.Label(
    frame1,
    text="Chords for k,l,:,'",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

#label for zxcv
tk.Label(
    frame1,
    text="Chords for z,x,c,v,b,n,m",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

tk.Label(
    frame1,
    text="Chords for <,>,?",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()


root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

app = tk.Tk()

# Create a list of label texts and options for dropdown menus
labels_and_options = [
    ("Label 1", ["Option 1-1", "Option 1-2", "Option 1-3"]),
    ("Label 2", ["Option 2-1", "Option 2-2", "Option 2-3"]),
    ("Label 3", ["Option 3-1", "Option 3-2", "Option 3-3"]),
    ("Label 4", ["Option 4-1", "Option 4-2", "Option 4-3"])
]

for label_text, options in labels_and_options:
    frame = tk.Frame(app)
    frame.pack()

    # Label
    my_label = tk.Label(frame, text=label_text)
    my_label.pack(side=tk.LEFT)

    # First OptionMenu
    # selected_option1 = tk.StringVar(frame, value=options[0])
    # option_menu1 = ttk.Combobox(frame, textvariable=selected_option1, values=options, state="readonly")
    # option_menu1.pack(side=tk.LEFT)

    chords = "7ths 9ths add11s ".split()
    chord_var = tk.StringVar(frame, value=chords[0])
    chords_dropdown = tk.OptionMenu(frame,scale_var, *chords)
    chords_dropdown.config(font=("TkMenuFont",12), width=10)
    menu = frame.nametowidget(chords_dropdown.menuname)
    menu.config(font=("TkMenuFont",12))
    chords_dropdown.pack(side=tk.LEFT)

    # Second OptionMenu
    chords = "3 4 5 ".split()
    chord_var = tk.StringVar(frame, value=chords[0])
    chords_dropdown = tk.OptionMenu(frame,scale_var, *chords)
    chords_dropdown.config(font=("TkMenuFont",12), width=10)
    menu = frame.nametowidget(chords_dropdown.menuname)
    menu.config(font=("TkMenuFont",12))
    chords_dropdown.pack(side=tk.LEFT)
    
    # Label
    my_label = tk.Label(frame, text=label_text)
    my_label.pack(side=tk.LEFT)

    # First OptionMenu
    chords = "7ths 9ths add11s ".split()
    chord_var = tk.StringVar(frame, value=chords[0])
    chords_dropdown = tk.OptionMenu(frame,scale_var, *chords)
    chords_dropdown.config(font=("TkMenuFont",12), width=10)
    menu = frame.nametowidget(chords_dropdown.menuname)
    menu.config(font=("TkMenuFont",12))
    chords_dropdown.pack(side=tk.LEFT)

    # Second OptionMenu
    chords = "3 4 5 ".split()
    chord_var = tk.StringVar(frame, value=chords[0])
    chords_dropdown = tk.OptionMenu(frame,scale_var, *chords)
    chords_dropdown.config(font=("TkMenuFont",12), width=10)
    menu = frame.nametowidget(chords_dropdown.menuname)
    menu.config(font=("TkMenuFont",12))
    chords_dropdown.pack(side=tk.LEFT)

app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 29
#      27 chords = "7ths 9ths add11s ".split()
#      28 chord_var = tk.StringVar(frame, value=chords[0])
# ---> 29 chords_dropdown = tk.OptionMenu(frame,scale_var, *chords)
#      30 chords_dropdown.config(font=("TkMenuFont",12), width=10)
#      31 menu = frame.nametowidget(chords_dropdown.menuname)
#
# NameError: name 'scale_var' is not defined

# %%
import tkinter as tk
from tkinter import ttk

app = tk.Tk()

#main box
frame1 = tk.Frame(app, width=500, height=600, bg=brown)
# frame1.grid(row=0,column=0)
frame1.pack()
frame1.pack_propagate(False)



chords = "7th(1.3.5.7) add9th(1.3.5.9) add11th(3.5.8.11) iii79(1.3.7.9) 5911(1.5.9.11) 5913(1.5.9.13) 1369(1.3.6.9) alt7th(1.5.7.10)".split()
octaves = "2 3 4 5".split()

f1 = tk.Frame(frame1)
f1.pack()
# f1.pack(side=tk.LEFT, padx=5)

#label for 1,2,3
tk.Label(
    f1,
    text="Chords for 1,2,3,4,5,6,7",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack(side=tk.LEFT)

chord_var1 = tk.StringVar(f1,value=chords[0])
chords_dropdown1 = tk.OptionMenu(f1,chord_var1, *chords)
chords_dropdown1.config(font=("TkMenuFont",12))
menu = f1.nametowidget(chords_dropdown1.menuname)
menu.config(font=("TkMenuFont",12))
chords_dropdown1.pack(side=tk.LEFT)

key_var1 = tk.StringVar(f1,value=octaves[0])
keys_dropdown1 = tk.OptionMenu(f1,key_var1, *octaves)
keys_dropdown1.config(font=("TkMenuFont",12))
menu = f1.nametowidget(keys_dropdown1.menuname)
menu.config(font=("TkMenuFont",12))
keys_dropdown1.pack(side=tk.LEFT)


f2 = tk.Frame(frame1)
f2.pack()
# f1.pack(side=tk.LEFT, padx=5)

tk.Label(
    f2,
    text="Chords for 8,9,0,-,=",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack(side=tk.LEFT)

chord_var2 = tk.StringVar(f2,value=chords[0])
chords_dropdown2 = tk.OptionMenu(f2,chord_var2, *chords)
chords_dropdown2.config(font=("TkMenuFont",12))
menu = f2.nametowidget(chords_dropdown2.menuname)
menu.config(font=("TkMenuFont",12))
chords_dropdown2.pack(side=tk.LEFT)

key_var2 = tk.StringVar(f2,value=octaves[0])
keys_dropdown2 = tk.OptionMenu(f2,key_var2, *octaves)
keys_dropdown2.config(font=("TkMenuFont",12))
menu = f2.nametowidget(keys_dropdown2.menuname)
menu.config(font=("TkMenuFont",12))
keys_dropdown2.pack(side=tk.LEFT)


f3 = tk.Frame(frame1)
f3.pack()
#label for qwert
tk.Label(
    f3,
    text="Chords for q,w,e,r,t,y,u",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack(side=tk.LEFT)

chord_var3 = tk.StringVar(f3,value=chords[0])
chords_dropdown3 = tk.OptionMenu(f3,chord_var3, *chords)
chords_dropdown3.config(font=("TkMenuFont",12))
menu = f3.nametowidget(chords_dropdown3.menuname)
menu.config(font=("TkMenuFont",12))
chords_dropdown3.pack(side=tk.LEFT)

key_var3 = tk.StringVar(f3,value=octaves[0])
keys_dropdown3 = tk.OptionMenu(f3,key_var3, *octaves)
keys_dropdown3.config(font=("TkMenuFont",12))
menu = f3.nametowidget(keys_dropdown3.menuname)
menu.config(font=("TkMenuFont",12))
keys_dropdown3.pack(side=tk.LEFT)



tk.Label(
    frame1,
    text="Chords for i,o,p,[,],|",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

#label for asdf
tk.Label(
    frame1,
    text="Chords for a,s,d,f,g,h,j",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

tk.Label(
    frame1,
    text="Chords for k,l,:,'",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

#label for zxcv
tk.Label(
    frame1,
    text="Chords for z,x,c,v,b,n,m",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

tk.Label(
    frame1,
    text="Chords for <,>,?",
    bg=brown,
    fg=white,
    font=("TkMenuFont",14)
).pack()

app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 app = tk.Tk()
#       6 #main box
# ----> 7 frame1 = tk.Frame(app, width=500, height=600, bg=brown)
#       8 # frame1.grid(row=0,column=0)
#       9 frame1.pack()
#
# NameError: name 'brown' is not defined

# %%
import tkinter as tk
from tkinter import ttk

app = tk.Tk()

#main box
frame1 = tk.Frame(app, width=500, height=600, bg=brown)
# frame1.grid(row=0,column=0)
frame1.pack()
frame1.pack_propagate(False)


chords = "7th(1.3.5.7) add9th(1.3.5.9) add11th(3.5.8.11) iii79(1.3.7.9) 5911(1.5.9.11) 5913(1.5.9.13) 1369(1.3.6.9) alt7th(1.5.7.10)".split()
octaves = "2 3 4 5".split()
s = "1,2,3,4,5,6,7~8,9,0,-,=~q,w,e,r,t,y,u~i,o,p,[,]\~a,s,d,f,g,h,j~k,l,;'~z,x,c,v,b,n,m~<,>,/".split('~')

chord_var = [tk.StringVar()] * 8
key_var = [tk.StringVar()] * 8

for i in range(8):
    f1 = tk.Frame(frame1)
    f1.pack()
    # f1.pack(side=tk.LEFT, padx=5)

    #label for 1,2,3
    tk.Label(
        f1,
        text=f"Chords for {s[i]}",
        bg=brown,
        fg=white,
        font=("TkMenuFont",14),
        width=20
    ).pack(side=tk.LEFT)

    chord_var[i] = tk.StringVar(f1,value=chords[0])
    chords_dropdown1 = tk.OptionMenu(f1,chord_var[i], *chords)
    chords_dropdown1.config(font=("TkMenuFont",12),width=13)
    menu = f1.nametowidget(chords_dropdown1.menuname)
    menu.config(font=("TkMenuFont",12))
    chords_dropdown1.pack(side=tk.LEFT)

    key_var[i] = tk.StringVar(f1,value=octaves[0])
    keys_dropdown1 = tk.OptionMenu(f1,key_var[i], *octaves)
    keys_dropdown1.config(font=("TkMenuFont",12),width=11)
    menu = f1.nametowidget(keys_dropdown1.menuname)
    menu.config(font=("TkMenuFont",12))
    keys_dropdown1.pack(side=tk.LEFT)

def on_closing():
    for i in range(8):
        print(f"{i}. Chord: {chord_var[i].get()} Octave: {key_var[i].get()}")
    app.destroy()

app.protocol("WM_DELETE_WINDOW",on_closing)

app.mainloop()
# Out:
# 0. Chord: 5913(1.5.9.13) Octave: 2
# 1. Chord: 5911(1.5.9.11) Octave: 5
# 2. Chord: 7th(1.3.5.7) Octave: 2
# 3. Chord: 7th(1.3.5.7) Octave: 3
# 4. Chord: 1369(1.3.6.9) Octave: 2
# 5. Chord: 7th(1.3.5.7) Octave: 4
# 6. Chord: 7th(1.3.5.7) Octave: 4
# 7. Chord: iii79(1.3.7.9) Octave: 2

# %%
import tkinter as tk

root = tk.Tk()
ab = [tk.StringVar()] * 8
ab[0] = "Bruh"
ab[5] = "Time"

# %%
for i in range(8):
    print(ab[i])
# Out:
# Bruh
# PY_VAR375
# PY_VAR375
# PY_VAR375
# PY_VAR375
# Time
# PY_VAR375
# PY_VAR375
